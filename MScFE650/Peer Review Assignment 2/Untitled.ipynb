# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create data
N = 60
g1 = (0.6 + 0.6 * np.random.rand(N), np.random.rand(N))
g2 = (0.4+0.3 * np.random.rand(N), 0.5*np.random.rand(N))
g3 = (0.3*np.random.rand(N),0.3*np.random.rand(N))

data = (g1, g2, g3)
colors = ("red", "green", "blue")
groups = ("coffee", "tea", "water")

# %%
# Create plot
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

for data, color, group in zip(data, colors, groups):
    x, y = data
    ax.scatter(x, y, alpha=0.8, c=color, edgecolors='none', s=30, label=group)

plt.title('Matplot scatter plot')
plt.legend(loc=2)
plt.show()

# %%
data
# Out:
# (array([0.19121099, 0.1574601 , 0.04338091, 0.2386202 , 0.13663608,
#         0.18065289, 0.028736  , 0.04325273, 0.21052554, 0.26033681,
#         0.28548751, 0.06415581, 0.11302082, 0.02295352, 0.1640405 ,
#         0.14012633, 0.02601891, 0.13866643, 0.07859942, 0.00380096,
#         0.15404329, 0.29098401, 0.02436865, 0.08217984, 0.24402912,
#         0.15693674, 0.17864959, 0.09134175, 0.1357345 , 0.08813516,
#         0.08966573, 0.01089578, 0.14438081, 0.18166183, 0.10981604,
#         0.02906177, 0.24376761, 0.27954909, 0.17929242, 0.06481794,
#         0.24659497, 0.26111567, 0.01909341, 0.10513232, 0.00617868,
#         0.02879728, 0.09789977, 0.21417733, 0.12545972, 0.21310657,
#         0.00944622, 0.10984757, 0.24249453, 0.11032914, 0.01256856,
#         0.06994925, 0.10538389, 0.0841039 , 0.10265466, 0.03210653]),
#  array([0.10456762, 0.15519045, 0.11969212, 0.22505516, 0.14458671,
#         0.21207243, 0.17152007, 0.06999721, 0.19472564, 0.14204331,
#         0.09317086, 0.04100814, 0.02156308, 0.19696344, 0.24481001,
#         0.03654308, 0.22247255, 0.12285472, 0.28569449, 0.01948102,
#         0.27909627, 0.202988  , 0.13549054, 0.02638533, 0.06460806,
#         0.04558503, 0.20615464, 0.16180559, 0.22451992, 0.12343474,
#         0.05792634, 0.18207159, 0.13995172, 0.07940518, 0.25641929,
#         0.08012167, 0.1386011 , 0.21167906, 0.17380113, 0.00294285,
#         0.15090132, 0.21743068, 0.1733107 , 0.21011516, 0.24312248,
#         0.10352819, 0.25229542, 0.0844158 , 0.10600575, 0.06225145,
#         0.0165564 , 0.2599141 , 0.05807524, 0.24160024, 0.22991688,
#         0.05711664, 0.06636791, 0.14819319, 0.09752063, 0.18791176]))
